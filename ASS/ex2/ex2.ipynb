# %% [markdown]
# # ELEC-E5510 — Exercise 2:

# %%
import numpy as np
import scipy.signal as signal
from scipy.signal import lfilter
import matplotlib.pyplot as plt

# %%
x=list(range(2,7))
test_err=[17.02,14.39,12.46,9.82,10.53]

plt.plot(x,test_err, label = "test_err")

# plt.plot(x,test_acc,label = "test")

plt.xlabel("Model number")
plt.ylabel("Error rate")
plt.legend()
plt.title("Error rate in different models")
plt.show()

# %%
x=list(range(2,7))
log_prob=[-77.3,-75.9,-74.5,-73.4,-72.3]

plt.plot(x,log_prob, label = "log_prob")

# plt.plot(x,test_acc,label = "test")

plt.xlabel("Model number")
plt.ylabel("Average log prob")
plt.legend()
plt.title("Average log prob in different models")
plt.show()
